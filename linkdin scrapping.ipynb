# %%
from flask import Flask, request,jsonify
import requests
from  bs4 import BeautifulSoup as bs
from urllib.request import urlopen as urReq

# %%
linkdin_url="https://www.linkedin.com/jobs/search/?keywords="+"datascientist"

# %%
linkdin_url
# Out:
# 'https://www.linkedin.com/jobs/search/?keywords=datascientist'

# %%
response_website=urReq(linkdin_url)

# %%
linkidin_read=response_website.read()

# %%
linkindin_html=bs(linkidin_read,"html.parser")

# %%
linkindin_html.find_all("ul", {"class":"scaffold-layout__list-container" })
# Out:
# []

# %%
linkindin_html.find_all("div", {"class":"jobs-search-results-list" })
# Out:
# []

# %%
linkindin_html
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="d_jobs_guest_search" name="pageKey"/>
# <meta content="urlType=jserp_custom;emptyResult=false" name="linkedin:pageTag"/>
# <meta content="en_US" name="locale"/>
# <meta data-app-version="2.0.1188" data-browser-id="51382cf7-8cb7-4835-8bb0-9d867c28f605" data-call-tree-id="AAXt1OSfaY3Ec+GIIEWwHw==" data-disable-jsbeacon-pagekey-suffix="false" data-enable-page-view-heartbeat-tracking="" data-member-id="0" data-multiproduct-name="jobs-guest-frontend" data-page-instance="urn:li:page:d_jobs_guest_search;NS9hc3+pShOKfmjc7sGQsQ==" data-service-name="jobs-guest-frontend" id="config"/>
# <link href="https://www.linkedin.com/jobs/datascientist-jobs" rel="canonical"/>
# <!-- --><!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <link href="https://static-exp1.licdn.com/aero-v1/sc/h/al2o9zrvru7aqj8e1x2rzsrca" rel="icon"/>
# <script>
# ...
